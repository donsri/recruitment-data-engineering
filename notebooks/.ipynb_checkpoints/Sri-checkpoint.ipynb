# %% [markdown]
# # Update circuits
#
# This script searches for new circuits from the 'circuits.csv' file in the Minio object store. It compares them against circuits already listed in the database and inserts any new ones.
#
# #### ToDo:
# - Improve the matching logic, it is susceptible to false positives.
# - Quarantine records that may be incorrect.
# - Add a results reporting function.
# - Add additional metadata.
# - Make logic performance improvements.

# %%
import pandas as pd
from io import BytesIO
from minio import Minio
from sqlalchemy import create_engine, text
from fuzzywuzzy import fuzz

# %%
# Initialize Minio client
minio_client = Minio(
    "minio:9000",
    access_key="minioadmin",
    secret_key="minioadmin",
    secure=False
)

# Download the CSV file from the Minio bucket into a pandas DataFrame
data = minio_client.get_object("track.data-raw", "circuits.csv")
data = BytesIO(data.read())
df_csv = pd.read_csv(data)
# display(df_csv)
# df = df_csv.where(df_csv["circuitId"] == 2)
len(df_csv)
# Out:
# 77

# %%
df_csv.head(20)
# Out:
#     circuitId      circuitRef                            name      location  \
# 0           1     albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1           2          sepang    Sepang International Circuit  Kuala Lumpur
# 2           3         bahrain   Bahrain International Circuit        Sakhir
# 3           4       catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4           5        istanbul                   Istanbul Park      Istanbul
# 5           6          monaco               Circuit de Monaco   Monte-Carlo
# 6           7      villeneuve       Circuit Gilles Villeneuve      Montreal
# 7           8     magny_cours   Circuit de Nevers Magny-Cours   Magny Cours
# 8           9     silverstone             Silverstone Circuit   Silverstone
# 9          10  hockenheimring                  Hockenheimring    Hockenheim
# 10         11     hungaroring                     Hungaroring      Budapest
# 11         12        valencia         Valencia Street Circuit      Valencia
# 12         13             spa    Circuit de Spa-Francorchamps           Spa
# 13         14           monza    Autodromo Nazionale di Monza         Monza
# 14         15      marina_bay       Marina Bay Street Circuit    Marina Bay
# 15         16            fuji                   Fuji Speedway         Oyama
# 16         17        shanghai  Shanghai International Circuit      Shanghai
# 17         18      interlagos      Autódromo José Carlos Pace     São Paulo
# 18         19    indianapolis     Indianapolis Motor Speedway  Indianapolis
# 19         20     nurburgring                     Nürburgring       Nürburg
#
#       country       lat         lng  alt  \
# 0   Australia -37.84970  144.968000   10
# 1    Malaysia   2.76083  101.738000   18
# 2     Bahrain  26.03250   50.510600    7
# 3       Spain  41.57000    2.261110  109
# 4      Turkey  40.95170   29.405000  130
# 5      Monaco  43.73470    7.420560    7
# 6      Canada  45.50000  -73.522800   13
# 7      France  46.86420    3.163610  228
# 8          UK  52.07860   -1.016940  153
# 9     Germany  49.32780    8.565830  103
# 10    Hungary  47.57890   19.248600  264
# 11      Spain  39.45890   -0.331667    4
# 12    Belgium  50.43720    5.971390  401
# 13      Italy  45.61560    9.281110  162
# 14  Singapore   1.29140  103.864000   18
# 15      Japan  35.37170  138.927000  583
# 16      China  31.33890  121.220000    5
# 17     Brazil -23.70360  -46.699700  785
# 18        USA  39.79500  -86.234700  223
# 19    Germany  50.33560    6.947500  578
#
#                                                   url
# 0   http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1   http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2   http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3   http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4          http://en.wikipedia.org/wiki/Istanbul_Park
# 5      http://en.wikipedia.org/wiki/Circuit_de_Monaco
# 6   http://en.wikipedia.org/wiki/Circuit_Gilles_Vi...
# 7   http://en.wikipedia.org/wiki/Circuit_de_Nevers...
# 8    http://en.wikipedia.org/wiki/Silverstone_Circuit
# 9         http://en.wikipedia.org/wiki/Hockenheimring
# 10           http://en.wikipedia.org/wiki/Hungaroring
# 11  http://en.wikipedia.org/wiki/Valencia_Street_C...
# 12  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...
# 13  http://en.wikipedia.org/wiki/Autodromo_Naziona...
# 14  http://en.wikipedia.org/wiki/Marina_Bay_Street...
# 15         http://en.wikipedia.org/wiki/Fuji_Speedway
# 16  http://en.wikipedia.org/wiki/Shanghai_Internat...
# 17  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jo...
# 18  http://en.wikipedia.org/wiki/Indianapolis_Moto...
# 19      http://en.wikipedia.org/wiki/N%C3%BCrburgring

# %%
# Initialize connection to the PostgreSQL database using SQLAlchemy
engine = create_engine('postgresql://admin:admin@pgdb/postgres')

# %%
# Query the database to get the current circuits
df_db = pd.read_sql("SELECT * FROM race_data.circuits", engine)

# %%
len(df_db)
# Out:
# 25

# %%
# Merge the both resulyts and get result dataframe
df_result = pd.merge(df_csv, df_db['name'],
                       how='left', on=['name'],indicator=True)

len(df_result)
display(df_result)
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# 2         Sakhir       Bahrain  26.03250   50.51060    7
# 3       Montmeló         Spain  41.57000    2.26111  109
# 4       Istanbul        Turkey  40.95170   29.40500  130
# ..           ...           ...       ...        ...  ...
# 72      Portimão      Portugal  37.22700   -8.62670  108
# 73       Mugello         Italy  43.99750   11.37190  255
# 74        Jeddah  Saudi Arabia  21.63190   39.10440   15
# 75     Al Daayen         Qatar  25.49000   51.45420   \N
# 76         Miami           USA  25.95810  -80.23890   \N
#
#                                                   url     _merge
# 0   http://en.wikipedia.org/wiki/Melbourne_Grand_P...  left_only
# 1   http://en.wikipedia.org/wiki/Sepang_Internatio...  left_only
# 2   http://en.wikipedia.org/wiki/Bahrain_Internati...       both
# 3   http://en.wikipedia.org/wiki/Circuit_de_Barcel...       both
# 4          http://en.wikipedia.org/wiki/Istanbul_Park  left_only
# ..                                                ...        ...
# 72  http://en.wikipedia.org/wiki/Algarve_Internati...       both
# 73       http://en.wikipedia.org/wiki/Mugello_Circuit       both
# 74  http://en.wikipedia.org/wiki/Jeddah_Street_Cir...  left_only
# 75  http://en.wikipedia.org/wiki/Losail_Internatio...  left_only
# 76  http://en.wikipedia.org/wiki/Miami_Internation...       both
#
# [77 rows x 10 columns]

# %%
df_final = df_result[df_result['_merge'] == 'left_only']
df_final = df_final[['circuitRef', 'name','location','lat','lng']]
df_final = df_final.rename(columns={'circuitRef': 'circuit_reference'})
len(df_final)
# display(df_final)
query = text(f""" 
INSERT INTO race_data.circuits(circuit_reference, name, location, lat, lng)
VALUES {','.join([str(i) for i in list(df_final.to_records(index=False))])}
""")
# engine.execute(query)
with engine.begin() as connection:
    connection.execute(query)
#     df_final.to_sql('race_data.circuits', connection)

# %%
# Define a threshold for the fuzz.ratio. This depends on how strict you want your matching to be.
threshold = 80

# %%
for index, row in df_csv.iterrows():
    csv_circuit_name = row['name']
    csv_circuit = row[['circuitId', 'circuitRef', 'name', 'location', 'lat', 'lng']]
    match_found = False

    for _, db_row in df_db.iterrows():
        db_circuit_name = db_row['name']

        # Compare the circuit names using fuzzy matching
        if fuzz.ratio(csv_circuit_name.lower(), db_circuit_name.lower()) > threshold:
            match_found = True
            break

    # If no match is found, upsert the circuit into the database
    if not match_found:
        # The values need to be adapted according to the columns in your table
        print("I am inside")
        insert_query = text("""
        INSERT INTO race_data.circuits 
        (circuit_reference, name, location, lat, lng) 
        VALUES (:circuitRef, :name, :location, :lat, :lng)
        """)
        csv_circuit_dict = csv_circuit.to_dict()
        del csv_circuit_dict['circuitId']  # remove 'circuitId' from the dict if it exists
        with engine.begin() as connection:
            connection.execute(insert_query, csv_circuit_dict)
# Out:
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside
# I am inside

# %%
# Show the final ressult for circuits:
# Query the database to get the current circuits
df_db = pd.read_sql("SELECT * FROM race_data.circuits", engine)

# Set max rows displayed in output to None
pd.set_option('display.max_rows', None)

# Display the DataFrame
df_db
# Out:
#     circuit_id circuit_reference  \
# 0            1          Montreal
# 1            2         Melbourne
# 2            3         Spielberg
# 3            4       Silverstone
# 4            5         Barcelona
# 5            6               Spa
# 6            7             Monza
# 7            8             Sochi
# 8            9       Nurburgring
# 9           10          Portimao
# 10          11           Mugello
# 11          12            Sakhir
# 12          13             Imola
# 13          14            Monaco
# 14          15              Baku
# 15          16       Paul Ricard
# 16          17       Hungaroring
# 17          18         Zandvoort
# 18          19             Hanoi
# 19          20            Austin
# 20          21            Mexico
# 21          22            Jeddah
# 22          23         Abu Dhabi
# 23          24         Las Vegas
# 24          25             Miami
# 25          26       albert_park
# 26          27            sepang
# 27          28          istanbul
# 28          29        villeneuve
# 29          30       magny_cours
# 30          31    hockenheimring
# 31          32          valencia
# 32          33             monza
# 33          34        marina_bay
# 34          35              fuji
# 35          36          shanghai
# 36          37        interlagos
# 37          38      indianapolis
# 38          39             imola
# 39          40            suzuka
# 40          41             vegas
# 41          42            galvez
# 42          43             jerez
# 43          44           estoril
# 44          45           okayama
# 45          46          adelaide
# 46          47           kyalami
# 47          48         donington
# 48          49           phoenix
# 49          50           yeongam
# 50          51       jacarepagua
# 51          52           detroit
# 52          53      brands_hatch
# 53          54         zandvoort
# 54          55            zolder
# 55          56             dijon
# 56          57            dallas
# 57          58        long_beach
# 58          59            jarama
# 59          60      watkins_glen
# 60          61        anderstorp
# 61          62           mosport
# 62          63          montjuic
# 63          64          nivelles
# 64          65           charade
# 65          66         tremblant
# 66          67           essarts
# 67          68            lemans
# 68          69             reims
# 69          70            george
# 70          71           zeltweg
# 71          72           aintree
# 72          73          boavista
# 73          74         riverside
# 74          75              avus
# 75          76          monsanto
# 76          77           sebring
# 77          78          ain-diab
# 78          79           pescara
# 79          80        bremgarten
# 80          81         pedralbes
# 81          82             buddh
# 82          83          americas
# 83          84            jeddah
# 84          85            losail
#
#                                             name               location  \
# 0                      Circuit Gilles-Villeneuve               Montreal
# 1                   Melbourne Grand Prix Circuit              Melbourne
# 2                                  Red Bull Ring              Spielberg
# 3                            Silverstone Circuit            Silverstone
# 4                 Circuit de Barcelona-Catalunya               Montmelo
# 5                   Circuit de Spa-Francorchamps      Spa Francorchamps
# 6                      Autodromo Nazionale Monza                  Monza
# 7                                 Sochi Autodrom                  Sochi
# 8                                    Nürburgring                Nürburg
# 9             Autódromo Internacional do Algarve               Portimão
# 10          Autodromo Internazionale del Mugello  Scarperia e San Piero
# 11                 Bahrain International Circuit                 Sakhir
# 12  Autodromo Internazionale Enzo e Dino Ferrari                  Imola
# 13                             Circuit de Monaco            Monte Carlo
# 14                             Baku City Circuit                   Baku
# 15                           Circuit Paul Ricard           Le Castellet
# 16                                   Hungaroring               Mogyorod
# 17                             Circuit Zandvoort              Zandvoort
# 18                          Hanoi Street Circuit                  Hanoi
# 19                       Circuit of The Americas                 Austin
# 20                  Autódromo Hermanos Rodríguez            Mexico City
# 21                         Jeddah Street Circuit                 Jeddah
# 22                            Yas Marina Circuit              Abu Dhabi
# 23                      Las Vegas Street Circuit              Las Vegas
# 24                 Miami International Autodrome                  Miami
# 25                Albert Park Grand Prix Circuit              Melbourne
# 26                  Sepang International Circuit           Kuala Lumpur
# 27                                 Istanbul Park               Istanbul
# 28                     Circuit Gilles Villeneuve               Montreal
# 29                 Circuit de Nevers Magny-Cours            Magny Cours
# 30                                Hockenheimring             Hockenheim
# 31                       Valencia Street Circuit               Valencia
# 32                  Autodromo Nazionale di Monza                  Monza
# 33                     Marina Bay Street Circuit             Marina Bay
# 34                                 Fuji Speedway                  Oyama
# 35                Shanghai International Circuit               Shanghai
# 36                    Autódromo José Carlos Pace              São Paulo
# 37                   Indianapolis Motor Speedway           Indianapolis
# 38                 Autodromo Enzo e Dino Ferrari                  Imola
# 39                                Suzuka Circuit                 Suzuka
# 40                Las Vegas Strip Street Circuit              Las Vegas
# 41                 Autódromo Juan y Oscar Gálvez           Buenos Aires
# 42                             Circuito de Jerez   Jerez de la Frontera
# 43                          Autódromo do Estoril                Estoril
# 44                 Okayama International Circuit                Okayama
# 45                       Adelaide Street Circuit               Adelaide
# 46                                       Kyalami                Midrand
# 47                                Donington Park       Castle Donington
# 48                        Phoenix street circuit                Phoenix
# 49                  Korean International Circuit         Yeongam County
# 50         Autódromo Internacional Nelson Piquet         Rio de Janeiro
# 51                        Detroit Street Circuit                Detroit
# 52                                  Brands Hatch                   Kent
# 53                        Circuit Park Zandvoort              Zandvoort
# 54                                        Zolder         Heusden-Zolder
# 55                                 Dijon-Prenois                  Dijon
# 56                                     Fair Park                 Dallas
# 57                                    Long Beach             California
# 58                                        Jarama                 Madrid
# 59                                  Watkins Glen         New York State
# 60                          Scandinavian Raceway             Anderstorp
# 61                 Mosport International Raceway                Ontario
# 62                                      Montjuïc              Barcelona
# 63                              Nivelles-Baulers               Brussels
# 64                               Charade Circuit       Clermont-Ferrand
# 65                        Circuit Mont-Tremblant                 Quebec
# 66                             Rouen-Les-Essarts                  Rouen
# 67                                       Le Mans                Le Mans
# 68                                   Reims-Gueux                  Reims
# 69                         Prince George Circuit  Eastern Cape Province
# 70                                       Zeltweg                 Styria
# 71                                       Aintree              Liverpool
# 72                          Circuito da Boavista                 Oporto
# 73               Riverside International Raceway             California
# 74                                          AVUS                 Berlin
# 75                         Monsanto Park Circuit                 Lisbon
# 76                 Sebring International Raceway                Florida
# 77                                      Ain Diab             Casablanca
# 78                               Pescara Circuit                Pescara
# 79                            Circuit Bremgarten                   Bern
# 80                          Circuit de Pedralbes              Barcelona
# 81                   Buddh International Circuit          Uttar Pradesh
# 82                       Circuit of the Americas                 Austin
# 83                       Jeddah Corniche Circuit                 Jeddah
# 84                  Losail International Circuit              Al Daayen
#
#          lat         lng
# 0   45.50600  -73.525000
# 1  -37.84970  144.968000
# 2   47.22300   14.761000
# 3   52.07200   -1.017000
# 4   41.56900    2.261000
# 5   50.43600    5.971000
# 6   45.62100    9.290000
# 7   43.40700   39.960000
# 8   50.33400    6.943000
# 9   37.23200   -8.628000
# 10  43.99800   11.372000
# 11  26.03100   50.512000
# 12  44.34300   11.716000
# 13  43.73500    7.421000
# 14  40.37200   49.853000
# 15  43.25100    5.793000
# 16  47.58100   19.250000
# 17  52.38900    4.541000
# 18  21.02100  105.843000
# 19  30.13300  -97.641000
# 20  19.40600  -99.090000
# 21  21.52700   39.187000
# 22  24.47000   54.603000
# 23  36.16900 -115.136000
# 24  25.77800  -80.202000
# 25 -37.84970  144.968000
# 26   2.76083  101.738000
# 27  40.95170   29.405000
# 28  45.50000  -73.522800
# 29  46.86420    3.163610
# 30  49.32780    8.565830
# 31  39.45890   -0.331667
# 32  45.61560    9.281110
# 33   1.29140  103.864000
# 34  35.37170  138.927000
# 35  31.33890  121.220000
# 36 -23.70360  -46.699700
# 37  39.79500  -86.234700
# 38  44.34390   11.716700
# 39  34.84310  136.541000
# 40  36.11470 -115.173000
# 41 -34.69430  -58.459300
# 42  36.70830   -6.034170
# 43  38.75060   -9.394170
# 44  34.91500  134.221000
# 45 -34.92720  138.617000
# 46 -25.98940   28.076700
# 47  52.83060   -1.375280
# 48  33.44790 -112.075000
# 49  34.73330  126.417000
# 50 -22.97560  -43.395000
# 51  42.32980  -83.040100
# 52  51.35690    0.263056
# 53  52.38880    4.540920
# 54  50.98940    5.256940
# 55  47.36250    4.899130
# 56  32.77740  -96.758700
# 57  33.76510 -118.189000
# 58  40.61710   -3.585580
# 59  42.33690  -76.927200
# 60  57.26530   13.604200
# 61  44.04810  -78.675600
# 62  41.36640    2.151670
# 63  50.62110    4.326940
# 64  45.74720    3.038890
# 65  46.18770  -74.609900
# 66  49.33060    1.004580
# 67  47.95000    0.224231
# 68  49.25420    3.930830
# 69 -33.04860   27.873600
# 70  47.20390   14.747800
# 71  53.47690   -2.940560
# 72  41.17050   -8.673250
# 73  33.93700 -117.273000
# 74  52.48060   13.251400
# 75  38.71970   -9.203060
# 76  27.45470  -81.348300
# 77  33.57860   -7.687500
# 78  42.47500   14.150800
# 79  46.95890    7.401940
# 80  41.39030    2.116670
# 81  28.34870   77.533100
# 82  30.13280  -97.641100
# 83  21.63190   39.104400
# 84  25.49000   51.454200

# %%
## Check for false positives

# %%
# Define the last_index variable to track the last index used in the DataFrame
last_index = 0

# Define an empty DataFrame
duplicates = pd.DataFrame(columns=['index1', 'index2', 'circuit_reference1', 'circuit_reference2', 'name1', 'name2', 'location1', 'location2', 'score'])

for i in range(len(df_db)):
    for j in range(i+1, len(df_db)):
        circuit_reference1 = df_db.iloc[i]['circuit_reference']
        circuit_reference2 = df_db.iloc[j]['circuit_reference']
        name1 = df_db.iloc[i]['name']
        name2 = df_db.iloc[j]['name']
        location1 = df_db.iloc[i]['location']
        location2 = df_db.iloc[j]['location']
        
        # Calculate the fuzzy match score for circuit_reference, name and location fields
        circuit_reference_score = fuzz.ratio(circuit_reference1.lower(), circuit_reference2.lower())
        name_score = fuzz.ratio(name1.lower(), name2.lower())
        location_score = fuzz.ratio(location1.lower(), location2.lower())
        
        # If the score is above a threshold (e.g. 80) for circuit_reference, name or location, consider them as potential duplicates
        if circuit_reference_score > 80 or name_score > 80 or location_score > 80:
            duplicates.loc[last_index] = {
                'index1': df_db.iloc[i]['circuit_id'],
                'index2': df_db.iloc[j]['circuit_id'],
                'circuit_reference1': circuit_reference1,
                'circuit_reference2': circuit_reference2,
                'name1': name1,
                'name2': name2,
                'location1': location1,
                'location2': location2,
                'score': max(circuit_reference_score, name_score, location_score)
            }
            last_index += 1

# Show the potential duplicates
duplicates
# Out:
#     index1  index2 circuit_reference1 circuit_reference2  \
# 0        1      29           Montreal         villeneuve
# 1        2      26          Melbourne        albert_park
# 2        7      33              Monza              monza
# 3       12      27             Sakhir             sepang
# 4       12      36             Sakhir           shanghai
# 5       12      45             Sakhir            okayama
# 6       12      50             Sakhir            yeongam
# 7       12      82             Sakhir              buddh
# 8       12      85             Sakhir             losail
# 9       13      39              Imola              imola
# 10      18      54          Zandvoort          zandvoort
# 11      19      32              Hanoi           valencia
# 12      19      49              Hanoi            phoenix
# 13      19      52              Hanoi            detroit
# 14      20      83             Austin           americas
# 15      22      84             Jeddah             jeddah
# 16      24      41          Las Vegas              vegas
# 17      27      36             sepang           shanghai
# 18      27      45             sepang            okayama
# 19      27      50             sepang            yeongam
# 20      27      85             sepang             losail
# 21      35      45               fuji            okayama
# 22      36      45           shanghai            okayama
# 23      36      50           shanghai            yeongam
# 24      36      82           shanghai              buddh
# 25      36      85           shanghai             losail
# 26      45      50            okayama            yeongam
# 27      45      85            okayama             losail
# 28      50      85            yeongam             losail
# 29      58      74         long_beach          riverside
# 30      62      77            mosport            sebring
# 31      63      81           montjuic          pedralbes
# 32      74      77          riverside            sebring
#
#                                            name1  \
# 0                      Circuit Gilles-Villeneuve
# 1                   Melbourne Grand Prix Circuit
# 2                      Autodromo Nazionale Monza
# 3                  Bahrain International Circuit
# 4                  Bahrain International Circuit
# 5                  Bahrain International Circuit
# 6                  Bahrain International Circuit
# 7                  Bahrain International Circuit
# 8                  Bahrain International Circuit
# 9   Autodromo Internazionale Enzo e Dino Ferrari
# 10                             Circuit Zandvoort
# 11                          Hanoi Street Circuit
# 12                          Hanoi Street Circuit
# 13                          Hanoi Street Circuit
# 14                       Circuit of The Americas
# 15                         Jeddah Street Circuit
# 16                      Las Vegas Street Circuit
# 17                  Sepang International Circuit
# 18                  Sepang International Circuit
# 19                  Sepang International Circuit
# 20                  Sepang International Circuit
# 21                                 Fuji Speedway
# 22                Shanghai International Circuit
# 23                Shanghai International Circuit
# 24                Shanghai International Circuit
# 25                Shanghai International Circuit
# 26                 Okayama International Circuit
# 27                 Okayama International Circuit
# 28                  Korean International Circuit
# 29                                    Long Beach
# 30                 Mosport International Raceway
# 31                                      Montjuïc
# 32               Riverside International Raceway
#
#                               name2       location1       location2  score
# 0         Circuit Gilles Villeneuve        Montreal        Montreal    100
# 1    Albert Park Grand Prix Circuit       Melbourne       Melbourne    100
# 2      Autodromo Nazionale di Monza           Monza           Monza    100
# 3      Sepang International Circuit          Sakhir    Kuala Lumpur     84
# 4    Shanghai International Circuit          Sakhir        Shanghai     88
# 5     Okayama International Circuit          Sakhir         Okayama     83
# 6      Korean International Circuit          Sakhir  Yeongam County     88
# 7       Buddh International Circuit          Sakhir   Uttar Pradesh     86
# 8      Losail International Circuit          Sakhir       Al Daayen     84
# 9     Autodromo Enzo e Dino Ferrari           Imola           Imola    100
# 10           Circuit Park Zandvoort       Zandvoort       Zandvoort    100
# 11          Valencia Street Circuit           Hanoi        Valencia     84
# 12           Phoenix street circuit           Hanoi         Phoenix     86
# 13           Detroit Street Circuit           Hanoi         Detroit     81
# 14          Circuit of the Americas          Austin          Austin    100
# 15          Jeddah Corniche Circuit          Jeddah          Jeddah    100
# 16   Las Vegas Strip Street Circuit       Las Vegas       Las Vegas    100
# 17   Shanghai International Circuit    Kuala Lumpur        Shanghai     90
# 18    Okayama International Circuit    Kuala Lumpur         Okayama     81
# 19     Korean International Circuit    Kuala Lumpur  Yeongam County     89
# 20     Losail International Circuit    Kuala Lumpur       Al Daayen     86
# 21    Okayama International Circuit           Oyama         Okayama     83
# 22    Okayama International Circuit        Shanghai         Okayama     81
# 23     Korean International Circuit        Shanghai  Yeongam County     83
# 24      Buddh International Circuit        Shanghai   Uttar Pradesh     81
# 25     Losail International Circuit        Shanghai       Al Daayen     86
# 26     Korean International Circuit         Okayama  Yeongam County     84
# 27     Losail International Circuit         Okayama       Al Daayen     84
# 28     Losail International Circuit  Yeongam County       Al Daayen     86
# 29  Riverside International Raceway      California      California    100
# 30    Sebring International Raceway         Ontario         Florida     83
# 31             Circuit de Pedralbes       Barcelona       Barcelona    100
# 32    Sebring International Raceway      California         Florida     83
